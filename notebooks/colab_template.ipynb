# %%
# !rm -r OptML-2023
# !git clone https://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@github.com/mohahf19/OptML-2023.git
# Out:
# rm: cannot remove 'OptML-2023': No such file or directory
# Cloning into 'OptML-2023'...
# remote: Enumerating objects: 303, done.
# remote: Counting objects: 100% (303/303), done.
# remote: Compressing objects: 100% (204/204), done.
# remote: Total 303 (delta 155), reused 223 (delta 84), pack-reused 0
# Receiving objects: 100% (303/303), 24.61 MiB | 33.33 MiB/s, done.
# Resolving deltas: 100% (155/155), done.

# %%
# !python --version
# Out:
# Python 3.10.12

# %%
# TODO: allow passing parameters over, remove tensor prints
# !python OptML-2023/neuralnets/batched/train_svrg.py
# Out:
# ...
# 100% 170498071/170498071 [00:01<00:00, 106684090.46it/s]
# Extracting data/cifar-10-python.tar.gz to data
# Files already downloaded and verified
# Started training..
#   0% 0/250 [00:00<?, ?it/s]tensor(0.) tensor(0.)
# Step: 0, Train Loss: 2.36275315284729, Test Loss: 2.3039987087249756
# tensor(0.8394) tensor(0.8394)
# tensor(1.4154) tensor(1.4154)
# tensor(1.9157) tensor(1.9157)
# tensor(2.1217) tensor(2.1217)
# tensor(2.1821) tensor(2.1821)
# tensor(2.1890) tensor(2.1890)
# tensor(2.2672) tensor(2.2672)
# tensor(2.3619) tensor(2.3619)
# tensor(2.1685) tensor(2.1685)
# tensor(2.0899) tensor(2.0899)
# tensor(1.9229) tensor(1.9229)
# tensor(1.8602) tensor(1.8602)
# tensor(1.7695) tensor(1.7695)
# tensor(1.7866) tensor(1.7866)
# tensor(1.9210) tensor(1.9210)
# tensor(1.8704) tensor(1.8704)
# tensor(1.9744) tensor(1.9744)
# tensor(1.8792) tensor(1.8792)
# tensor(1.7735) tensor(1.7735)
# tensor(1.6999) tensor(1.6999)
# tensor(1.5623) tensor(1.5623)
# tensor(1.4578) tensor(1.4578)
# ...
